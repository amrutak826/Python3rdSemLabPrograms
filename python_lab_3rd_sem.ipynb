# %%
n=int(input("enter a natural no"))
if(n<=0):
    print("Invalid")
    while(n<=0):
        y=int(input("Enter a nat no"))
        n=y
def recurSum(x):
    if(x==1):
        return 1
    elif(x<=0):
        print("Enet a valid no")
    else:
        return (x+recurSum(x-1))
print(recurSum(n))

# %%
# 1
n = int(input("Enter a natural number: "))
if n <= 0:
    print("Invalid input.")
    while n <= 0:
        n = int(input("Please enter a natural number: "))

def recurSum(x):
    if x == 1:
        return 1
    elif x<=1:
        return x
    else:
        return x + recurSum(x - 1)

print("Sum of n natural no is:",recurSum(n))

# %%
# 2
string=input("Enter a string")
words=string.split()
dictionary={}
for word in words:
    dictionary [word[0]].word
print(dictionary)

# %%
string = input("Enter a string: ")
words = string.split()
dictionary = {}

for word in words:
    # Check if the first letter is already a key in the dictionary
    if word[0] in dictionary:
        # Append the word to the existing list of words
        dictionary[word[0]].append(word)
    else:
        # Create a new list with the word if key doesn't exist
        dictionary[word[0]] = [word]

print(dictionary)

# %%
# 3
def count_char(s):
    char_count={}
    for char in s:
        if char.isalpha():
            if char in char_count:
                char_count[char]+=1
            else:
                char_count[char]=1
    return char_count
string=input("Enter a sring")
Dict=count_char(string)
for char,count in Dict.items():
    print(f"{char}:{count}" )

# %%
# 4 not required
my_list = []

def append_element(my_list):
    element = int(input("Enter an element to append: "))
    my_list.append(element)

def delete_element(my_list):
    if not my_list:
        print("List is empty")
    else:
        my_list.pop()

def display_elements(my_list):
    if not my_list:
        print("The list is empty")
    else:
        print("Elements present are:")
        for item in my_list:
            print(item)

print("Menu")
print("1. Append element")
print("2. Delete element")
print("3. Display")
print("4. Exit")

while True:
    choice = int(input("Enter your choice: "))
    if choice == 1:
        append_element(my_list)
    elif choice == 2:
        delete_element(my_list)
    elif choice == 3:
        display_elements(my_list)
    elif choice == 4:
        break
    else:
        print("Invalid choice")

# %%
# 4 using classes n objects
class ListManager:
    def __init__(self):
        self.my_list = []

    def append_element(self):
        element = int(input("Enter an element to append: "))
        self.my_list.append(element)
        print(f"{element} has been added to the list.")

    def delete_element(self):
        if not self.my_list:
            print("The list is empty. Nothing to delete.")
        else:
            removed_element = self.my_list.pop()
            print(f"{removed_element} has been removed from the list.")

    def display_elements(self):
        if not self.my_list:
            print("The list is empty.")
        else:
            print("Elements present in the list are:")
            for item in self.my_list:
                print(item)


# Instantiate the ListManager object
manager = ListManager()

print("Menu")
print("1. Append element")
print("2. Delete element")
print("3. Display elements")
print("4. Exit")

while True:
    choice = int(input("Enter your choice: "))
    
    if choice == 1:
        manager.append_element()
    elif choice == 2:
        manager.delete_element()
    elif choice == 3:
        manager.display_elements()
    elif choice == 4:
        print("Exiting the program.")
        break
    else:
        print("Invalid choice. Please enter a number between 1 and 4.")

# %%
# 5
class A:
    def show(self):
        print("Method in Class A")

class B(A):
    def show(self):
        print("Method in Class B")

class C(A):
    def show(self):
        print("Method in Class C")

class D(C, B):
    pass  # No 'show' method defined in D; MRO will decide which one to use.

# Create an instance of class D
d = D()
d.show()  # This will call the show method based on the MRO

# Display the MRO for class D
print("Method Resolution Order (MRO) for class D:")
print(D.__mro__)

# %%
# 6
class Complex:
    def __init__(self, real, imag):
        self.real = real
        self.imag = imag

    def __add__(self, other):
        return Complex(self.real + other.real, self.imag + other.imag)

    def __sub__(self, other):
        return Complex(self.real - other.real, self.imag - other.imag)

    def __mul__(self, other):
        real_part = self.real * other.real - self.imag * other.imag
        imag_part = self.real * other.imag + self.imag * other.real
        return Complex(real_part, imag_part)

    def __str__(self):
        return f"{self.real} + {self.imag}i" if self.imag >= 0 else f"{self.real} - {-self.imag}i"


# Create two Complex number instances
c1 = Complex(3, 2)
c2 = Complex(1, 7)

# Perform addition
print("Addition:", c1 + c2)

# Perform subtraction
print("Subtraction:", c1 - c2)

# Perform multiplication
print("Multiplication:", c1 * c2)

# %%
# 7
import numpy as np
import time

n = 10**6
list1 = list(range(n))
list2 = list(range(n))

array1 = np.arange(n)
array2 = np.arange(n)

def add_array(array1, array2):
    return array1 + array2

def add_lists(list1, list2):
    return [x + y for x, y in zip(list1, list2)]  # Fixed

# Timing for Python lists
start_time = time.time()
result_list = add_lists(list1, list2)
end_time = time.time()
list_time = end_time - start_time

# Timing for NumPy arrays
start_time = time.time()
result_array = add_array(array1, array2)
end_time = time.time()
array_time = end_time - start_time

print(f"Time taken for Python list: {list_time:.6f} seconds")
print(f"Time taken for NumPy addition: {array_time:.6f} seconds")
print(f"NumPy is approximately {list_time / array_time:.2f} times faster for this operation")

# %%
# 8
import pandas as pd

# Data for missing data analysis
data = {
    'name': ['Alia', 'Bob', 'Charlie', None, 'Eve'],
    'age': [25, None, 30, 22, None],
    'city': ['New York', 'Los Angeles', None, 'Chicago', 'Miami']
}

df = pd.DataFrame(data)

# Function to analyze missing data
def analyse_missing_data(df):
    print("DataFrame:")
    print(df)
    print("\nMissing Data Analysis:")

    missing_data = df.isnull().sum()
    print("Missing values in each column:")
    print(missing_data[missing_data > 0])

    missing_percentage = (missing_data / len(df)) * 100
    print("\nPercentage of missing values in each column:")
    print(missing_percentage[missing_percentage > 0])

    return missing_data, missing_percentage

# Function to handle missing data
def handle_missing_data(df):
    print("\nChoose a method to handle missing data:")
    print("1. Fill missing values with a specified value")
    print("2. Drop rows with missing values")
    print("3. Drop columns with missing values")
    choice = input("Enter your choice (1/2/3):")
    return choice

# Add calculate_correlation function
def calculate_correlation(df, column1, column2):
    return df[column1].corr(df[column2])

# Example data for probability and correlation analysis
prob_data = {
    'Variable_A': [1, 2, 3, 4, 5],
    'Variable_B': [2, 4, 6, 8, 10]
}

prob_df = pd.DataFrame(prob_data)

# Placeholder for probability functions (implementations not included in original code)
def joint_probability(df, event_A, event_B):
    # Mock implementation (replace with actual logic if needed)
    return 1 / 6

def marginal_probability(df, event, column):
    # Mock implementation (replace with actual logic if needed)
    return 1 / 6

def conditional_probability(df, event_A, event_B):
    joint_prob = joint_probability(df, event_A, event_B)
    marginal_prob = marginal_probability(df, event_B, 'Variable_B')
    if marginal_prob == 0:
        return 0
    return joint_prob / marginal_prob

# Analyze correlation
correlation = calculate_correlation(prob_df, 'Variable_A', 'Variable_B')
print("Correlation between Variable_A & Variable_B:", correlation)

# Compute probabilities
joint_prob = joint_probability(prob_df, 3, 4)
print("Joint Probability P(A=3 and B=4):", joint_prob)

marg_prob_A = marginal_probability(prob_df, 3, 'Variable_A')
print("Marginal Probability P(A=3):", marg_prob_A)

marg_prob_B = marginal_probability(prob_df, 4, 'Variable_B')
print("Marginal Probability P(B=4):", marg_prob_B)

cond_prob = conditional_probability(prob_df, 3, 4)
print("Conditional Probability P(A=3/B):", cond_prob)

# %%
# 9
import pandas as pd
import numpy as np
from scipy.stats import pearsonr

# Sample Data
data = {
    'Variable_A': [1, 2, 3, 4, 5, 6],
    'Variable_B': [2, 3, 4, 5, 6, 7]
}
df = pd.DataFrame(data)

# Function to calculate correlation
def calculate_correlation(df, col1, col2):
    correlation, _ = pearsonr(df[col1], df[col2])
    return correlation

# Joint Probability
def joint_probability(df, event_A, event_B):
    joint_df = df[(df['Variable_A'] == event_A) & (df['Variable_B'] == event_B)]
    joint_prob = len(joint_df) / len(df)
    return joint_prob

# Marginal Probability
def marginal_probability(df, event, variable):
    marginal_df = df[df[variable] == event]
    marginal_prob = len(marginal_df) / len(df)
    return marginal_prob

# Conditional Probability
def conditional_probability(df, event_A, event_B):
    joint_prob = joint_probability(df, event_A, event_B)
    marginal_prob = marginal_probability(df, event_B, 'Variable_B')
    if marginal_prob == 0:
        return 0
    return joint_prob / marginal_prob

# Analyze Missing Data
def analyse_missing_data(df):
    missing_data = df.isnull().sum()
    missing_percentage = (missing_data / len(df)) * 100
    print("\nPercentage of missing values in each column:")
    print(missing_percentage[missing_percentage > 0])
    return missing_data, missing_percentage

def handle_missing_data(df):
    while True:
        print("\nChoose a method to handle missing data:")
        print("1. Fill missing values with a specified value")
        print("2. Drop rows with missing values")
        print("3. Drop columns with missing values")
        print("4. Exiting................")
        choice = input("Enter your choice (1/2/3/4): ")
        
        if choice == '1':
            value = input("Enter the value to fill missing data: ")
            df_filled = df.fillna(value)
            print("\nData after filling missing values:")
            print(df_filled)
            #break  # Exit the loop after a valid operation
        elif choice == '2':
            df_dropped_rows = df.dropna()
            print("\nData after dropping rows with missing values:")
            print(df_dropped_rows)
            #break
        elif choice == '3':
            df_dropped_columns = df.dropna(axis=1)
            print("\nData after dropping columns with missing values:")
            print(df_dropped_columns)
            #break
        elif choice == '4':
            print("Exiting..............")
            break
        else:
            print("Invalid choice! Please enter 1, 2, or 3.")
            

        
# Example DataFrame with missing data
df_missing = pd.DataFrame({
    'name': ['Alia', 'Bob', 'Charlie', None, 'Eve'],
    'age': [25, None, 30, 22, None],
    'City': ['New York', 'Los Angeles', None, 'Chicago', 'Miami']
})

print("Original DataFrame:")
print(df_missing)

# Analyze Missing Data
missing_data, missing_percentage = analyse_missing_data(df_missing)

# Handle Missing Data
handle_missing_data(df_missing)
# Out:
# Original DataFrame:
#       name   age         City
# 0     Alia  25.0     New York
# 1      Bob   NaN  Los Angeles
# 2  Charlie  30.0         None
# 3     None  22.0      Chicago
# 4      Eve   NaN        Miami
#
# Percentage of missing values in each column:
# name    20.0
# age     40.0
# City    20.0
# dtype: float64
#
# Choose a method to handle missing data:
# 1. Fill missing values with a specified value
# 2. Drop rows with missing values
# 3. Drop columns with missing values
# 4. Exiting................
# Enter your choice (1/2/3/4): 4
# Exiting..............

# %%
# 10
import pandas as pd
import matplotlib.pyplot as plt

data={
    'age':[25,30,35,40,45,50,55,60, 65,70],
    'salary':[20000,25000,300000,35000,40000,45000,50000,55000,600000,65000],
    'department':['hr','it','finance','it','finance','hr','hr','finance','it','finance']
}

df=pd.DataFrame(data)
plt.figure(figsize=(8,5))
plt.scatter(df['age'],df['salary'],color='blue',marker='o')
plt.title("scatter plot of age vs salary")
plt.xlabel("age")
plt.ylabel("salary")
plt.grid(True)
plt.show()

plt.figure(figsize=(8,5))
plt.hist(df['age'],bins=5,color='green',edgecolor='black')
plt.title("Histogram of age distribution")
plt.xlabel("age")
plt.ylabel("frequency")
plt.grid(axis='y')
plt.show()

plt.figure(figsize=(8,5))
department_counts=df['department'].value_counts()
plt.bar(department_counts.index,department_counts.values,color='orange',edgecolor='black')
plt.title("bar plot of department count")
plt.xlabel("department")
plt.ylabel("no of employees")
plt.grid(axis='y')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# 11
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    'age': [25, 30, 35, 40, 45, 50, 55, 60, 65, 70],
    'salary': [20000, 25000, 30000, 35000, 40000, 45000, 50000, 55000, 60000, 65000],
    'department': ['hr', 'it', 'finance', 'it', 'finance', 'hr', 'hr', 'finance', 'it', 'finance']
}

# Create DataFrame
df = pd.DataFrame(data)

# Set Seaborn style
sns.set(style="whitegrid")

# Scatter plot of age vs salary
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='age', y='salary', hue='department', palette='viridis', s=100)
plt.title("Scatter plot of Age vs Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.legend(title='Department')
plt.show()

# Histogram of age distribution
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='age', bins=5, kde=True, color='purple')
plt.title("Histogram of Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# Bar plot of department counts
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='department', palette='pastel')
plt.title("Bar plot of Department Counts")
plt.xlabel("Department")
plt.ylabel("Number of Employees")
plt.show()

# %%
# 12
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    'Salary': [20000, 25000, 30000, 35000, 40000, 45000, 50000, 55000, 60000, 65000],
    'Department': ['HR', 'IT', 'Finance', 'IT', 'Finance', 'HR', 'HR', 'Finance', 'IT', 'Finance']
}

# Create DataFrame
df = pd.DataFrame(data)

# Set Seaborn style
sns.set(style="whitegrid")

# Create the boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Department', y='Salary', palette="pastel")

# Set the title and labels
plt.title("Box and Whiskers Plot of Salary by Department")
plt.xlabel("Department")
plt.ylabel("Salary")

# Show the plot
plt.show()
